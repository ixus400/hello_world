# %% [markdown]
# <a href="https://colab.research.google.com/github/ixus400/hello_world/blob/main/TEST_Forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 表格练习

# %%
# @title String fields

text = 'value' # @param {type:"string"}
dropdown = '1st option' # @param ["1st option", "2nd option", "3rd option"]
text_and_dropdown = 'value' # @param ["1st option", "2nd option", "3rd option"] {allow-input: true}
text_with_placeholder = '' # @param {type:"string", placeholder:"enter a value"}

print(text)
print(dropdown)
print(text_and_dropdown)
print(text_with_placeholder)

# %%
# @title String fields
text = 'value' # @param {type:"string"}
dropdown = '2nd option' # @param ["1st option", "2nd option", "3rd option"]
text_and_dropdown = 'value' # @param ["1st option", "2nd option", "3rd option"] {allow-input: true}
text_with_placeholder = 'this is a string' # @param {type:"string", placeholder:"enter a value"}

print(text)
# Out:
# value

# %%
#title raw input
raw_input = None # @param {type:"raw"}
raw_dropdown = raw_input # @param [1, "raw_input", "False", "'string'"] {type:"raw"}
raw_with_placeholder = None # @param {type:"raw", placeholder:"enter a value"}
